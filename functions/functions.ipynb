# %%
def sayhi():
    print("hello !!!")

sayhi()

# %%
def sayhi(name="guest"):
    print("hello",name)

sayhi("shoaib")
sayhi("afaaz")
sayhi()

# %%
def sayhi():
    return "hii shoaib"

sayhi()

# %%
def square(x):
    return x*x
def sumofsqs(x,y):
    return square(x)+square(y)

sq=sumofsqs(4,5)
print(sq)

# %%
def demo(a,b):
    return (a**2)+(b**2)+(2*a*b)

a=int(input("enter value of a"))
b=int(input("enter value of b"))
print(demo(a,b))

# %%
def findsumofeles(*nums):
    print(type(nums))
    return sum(nums)
sumof=findsumofeles(10,20,304,50,90)
print(sumof)

# %%
def dataof(**data):
    d=data
    return d
print(dataof(name="shoaib",age=19))

# %%
userMul=lambda x,y : x*y
print(userMul(10,20))
print("--------------")

def sq(x):
    return x*x
lst1=list(map(lambda x: x*x,))

# %%
def isprime(n):
    if n<=1:
        return False
    count=0
    for i in range(1,n+1):
        if n%1==0:
            count+=1
    return True if count == 2 else False

start=int(input("enter start value: "))
end=int(input("enter end value: "))
lst=[]

for i in range(start,end+1):
    if isprime(i)==True:
        lst.append(i)

print(lst)
print(len(lst))
# Out:
# [2]
# 1

# %%
class Node:
    def __init__(self,d):
        self.data=d
        self.next=none

class Main:
    @staticmethod
    def main():
        lst = [10,20,30]
        head=None
        node=Node(lst[0])
        head=node
        print(f"[{head.data} | {head.next}]at {head}")
        node=Node(lst[1])
        head.next=node
        print(f"[{head.data} | {head.next}]at {head}")
        print(f"[{head.next.data} | {head.next.next}] at {head.next}")
        node=Node(lst[2])
        head.next.next=node
        print(f"[{head.next.data} | {head.next.next}] at {head.next}")
        
        print(f"[{head.next.next.data} | {head.next.next.next}] at {head.next.next}")
