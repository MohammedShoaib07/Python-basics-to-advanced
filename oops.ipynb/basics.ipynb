# %%
student1={"name": "shoaib","branch":"aiml","roll":1}
student2={"name": "irfan","branch":"ds","roll":2}
student3={"name": "afaaz","branch":"ece","roll":3}

students=[student1,student2,student3]
roll=int(input("enter roll no :"))
for student in students:
    if student["roll"]==roll:
        print(f"student name : {student['name']}")
        print(f"student branch : {student['branch']}")
        print(f"student roll no : {student['roll']}")

# %%
class ID:
    def __init__(self,name,branch,phn,roll):
        self.name=name
        self.branch=branch
        self.phn=phn
        self.roll=roll

s1=ID("shoaib","aiml",9880558995)
s2=ID("yousuf","cse",9880434595)
s3=ID("irfan","ece",8746834595)

print(s1)

# %%
class Data:
    def __init__(self,n,a):
        self.name=n
        self.age=a
person= Data("shoaib",19)
print(person)
print(person.name)

print(person.age)

# %%
class Student:
    def __init__(self,n,a):
        self.name=n
        self.age=a
    def displayStudent(self):
        print("\nSTUDENT DETAILS\n")
        print(f"Name:{self.name}")
        print(f"Age:{self.age}")

n=input("ENTER NAME : ")
a=input("ENTER AGE : ")

s=Student(n,a)
s.displayStudent()

# %%
import random as r

class MyBank:
    def __init__(self,accno,name,balance):
        self.accno=accno
        self.name=name
        self.balance=balance
    
    def createcustomer(self):
        self.accno=r.randint(10000,60000)
        self.name=input("enter customer name :")
        self.balance=int(input("enter initial balance :"))

    def displaydetails(self):
        print(f"\ncustomer details\n")
        print(f"customer name : {self.name}")
        print(f"account number : {self.accno}")
        print(f"account balance : {self.balance}\n")

    def withdraw(self,amount):
        if amount > self.balance:
            print("INSUFFICIENT BALANCE\n")
        else:
            self.balance -=amount
            print(f"{amount} withdraw successful\n Available balance : {self.balance}\n")

    def deposit(self,amount):
        self.balance +=amount
        print(f"{amount} successfully deposited \n Available balance : {self.balance}")

customer=MyBank(12345,"shoaib",1000)

while True:
    print("1.create\n2.display\n3.withdraw\n4.deposit\n5.exit\n")
    ch=int(input("ENTER YOUR CHOICE :"))

    if ch==1:
        customer.createcustomer()
    elif ch==2:
        customer.displaydetails()
    elif ch==3:
        amount=int(input("ENTER AMOUNT TO WITHDRAW :"))
        customer.withdraw(amount)
    elif ch==4:
        amount=int(input("ENTER AMOUNT TO deposit :"))
        customer.deposit(amount)
    elif ch==5:
        print("EXITED !!!")
        break
    else:
        print("INVALID CHOICE")
# Out:
# 1.create
# 2.display
# 3.withdraw
# 4.deposit
# 5.exit
#
# 1.create
# 2.display
# 3.withdraw
# 4.deposit
# 5.exit
#
#
# customer details
#
# customer name : shoaib
# account number : 10325
# account balance : 1000
#
# 1.create
# 2.display
# 3.withdraw
# 4.deposit
# 5.exit
#
# EXITED !!!

# %%
class Venue:
    def __init__(self,venue,city):
        self.venue=venue
        self.city=city
    def displaydetails(self):
        print("Venue Details:")
        print(f"Venue Name: {self.venue}")
        print(f"City Name: {self.city}")
class Main:
    @staticmethod
    def main():
            venue=input().split(",")
Main.main()

# %%
class Venue:
    def __init__(self, venue, city):
        self.venue = venue
        self.city = city

    def displaydetails(self):
        print("Venue Details:")
        print()
        print(f"Venue Name: {self.venue}")
        print(f"City Name: {self.city}")


class Main:
    @staticmethod
    def main():
        ip = input().split(",")

        venue = ip[0].strip()
        city = ip[1].strip()

        v = Venue(venue, city)
        v.displaydetails()


Main.main()
# Out:
# Venue Details:
#
# Venue Name: M. A. Chidambaram Stadium
# City Name: Chennai
