# %%
class Demo:

    def __init__(self):
        self.__name=""
        self.__password=""
        self.__age=0
    
    def set_name(self,n):
        self.__name=n

    def get_name(self):
        return self.__name
    
    def set_password(self,p):
        self.__password=p

    def get_password(self):
        return self.__password

    def s_age(self,a):
        if a <= 0:
            print("invalid age")
        else:
            self.__age=a

    def g_age(self):
        return self.__age


class Main:
    @staticmethod
    def main():
        obj=Demo()
        obj.set_name("shoaib")
        obj.set_password("shoaib@123")
        obj.age(20)

# %%
class Animal:
    def sound(self):
        pass

class Dog(Animal):
    def sound(self):
        return "Bark"

class Cat(Animal):
    def sound(self):
        return "Meow"

class Lion(Animal):
    def sound(self):
        return "Roar"

class Snake(Animal):
    def sound(self):
        return "Hiss"

class Cow(Animal):
    def sound(self):
        return "Moo"

class Duck(Animal):
    def sound(self):
        return "Quack"

animals = {"Dog": Dog(),"Cat": Cat(),"Lion": Lion(),"Snake": Snake(),"Cow": Cow(),"Duck": Duck()}

s = input()

if s in animals:
    print(animals[s].sound())
else:
    print("Invalid Input")
# Out:
# Bark
