# %%
## STRING AND STRING CONCATINATION

name= "shoaib"
place= "ballari"
age= 19
marks= 100
value= 1


print(name,place)
print(name+str(age)+str(marks)+str(value))
print(name,age,end="this will be added at end of print")
print(name ,age ,marks ,value ,sep="@")

# %%
##write a program to print details and also in paragraph form

name= "shoaib"
age = 19
marks = 80.9

print(f"This is My Information:\n1)Name : {name}\n2)Age : {age}\n3)Marks : {marks}\nMy name is {name} and my age is {age} and, i got {marks} in my semester")

# %%
## TAKING INPUT FROM USER AND PRINTING DETAILS

name=str(input("Enter name : "))
age=int(input("Enter age : "))
cgpa=float(input("Enter cgpa : "))

print("STUDENT DETAILS \n")

print("Name :",name)
print("age :",age)
print("cgpa :",cgpa)

# %%
## ARTHMETIC OPERATORS

a=10
b=20

print("sum of a and b is:",a+b)
print("difference of a and b is:",a-b)
print("product of a and b is:",a*b)
print("division of a and b is:",a/b)
print("floor division of a and b is:",a//b)
print("modulus of a and b is:",a%b)
print("a to the power of b is:",a**b)

# %%
## ASSIGNMENT OPERATOR

a=10
b=20
b +=a
print(b)

# %%
a=int(input("enter a: "))
b=input("enter b: ")

print(type(a))
print(type(b))
d=int(b)
print(type(d))


c=10+10j
type(c)

# %%
a="121.1"
b=float(a)
print(type(b))

# %%
## NUMBER IS EVEN OR ODD

a=int(input("enter number"))
if (a%2==0):print("EVEN")
else:print("ODD")

# %%
## POSITIVE NEGATIVE OR ZERO

num=int(input("Enter number : "))

if num>0:
    print("THE GIVEN NUMBER IS POSITIVE")
elif num<0:
    print("THE GIVEN NUMBER IS NEGATIVE")
else:
    print("THE GIVEN NUMBER IS ZERO")

# %%
## TO CHECK WHETHER THE THE GIVEN YEAR IS LEAP YEAR OR NOT

year=int(input("Enter the year"))

if year%4==0:
    print(year,"is a leap year")
else:
    print(year,"is not a leap year")

# %%
a=int(input("enter 1st number"))
b=int(input("enter 2nd number"))
c=int(input("enter 3rd number"))

if (a>b & a>c): print("a is largest")
elif(b>a & b>c): print("b is largest")
else: print("c is largest")

# %%
marks = int(input("Enter your marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 60:
    print("Grade C")
elif marks >= 40:
    print("Grade D")
else:
    print("Fail")

# %%
## program to check whether the given number is a perfect number

num = int(input("enter the number to check : "))
sum =0

for i in range (1,num):
    if num%i ==0:
        print(i)
        sum +=i
    else:
        print("Not a perfect number")
        break
print("sum =",sum)

# %%
## TO FIND IF THE GIVEN NUMBER IS PRIME NUMBER OR NO

num1 =int(input("enter 1st number : "))
num2=int(input("enter 2nd number : "))
temp =0

if num1>num2:
    
    temp=num1
    num1=num2
    num2=temp

for i in range(num1,num2+1):
    if i>1:
        for j in range(2,i):
            if(i%j==0):
                break
        else:
            print(i)

# %%
## CHECK FOR STRONG NUMBER 
num = int(input("enter number to check : "))

f=num//100
m=(num//10)%10
l=num%10
def fact_nums(f,m,l):
    if f==0 or f==1:
        return 1
    else:
        fact1 = 1
        for i in range(1, f+1):
            fact1 = fact1 * i

    if m==0 or m==1:
        return 1
    else:
        fact2 = 1
        for i in range(1, m+1):
            fact2 = fact2 * i

    if l==0 or l==1:
        return 1
    else:
        fact3 = 1
        for i in range(1, l+1):
            fact3 = fact3 * i

    sum=fact1+fact2+fact3
    return(sum)

if fact_nums(f,m,l) ==num:
    print("strong number")
else:
    print("not a strong number")

# %%
n = int(input("Enter the number of terms: "))

a, b = 0, 1

for i in range(n):
    print(a, end=" ")
    a, b = b, a + b

# %%
## GCD AND LCM OF 2 NUMS (WITHOUT INBUILT FUNCTION)

m=int(input())
n=int(input())
if m%i==0 and n%i==0:
    gcd=i
print(gcd)

# %%
## PLAINDROME

num=int(input())
num2=int(input())

if num1==num2:
    print("plaindrome")
else:
    print("not plaindrome")

# %%
n=int(input())

for i in range (1,n+1):
    print(i)

# %%
## question 1
## write a python program to find the second largest and third smallest elements in a list 
# without using the sort () method

list=[2,5,7,9,3,6]

largest=0
sec_largest=0

for ele in list:
    if ele>largest:
        sec_largest=largest
        largest=ele
    elif ele>sec_largest and ele!=largest:
        sec_largest=i
print(sec_largest)

# %%
## given a list of integers write a python program for
#remove du

# %%
## sep elements into even and odd
list=[3,5,6,8,90,42,45,2]
list_even=[]
list_odd=[]
final=[]

for ele in list:
    if ele%2==0:
        list_even.append(ele)
    else:
        list_odd.append(ele)

list_even.sort()
list_odd.sort()
final=list_even+list_odd
print(final)

# %%
#

employees = [
    (101, "shoaib", "AIML", 45000),
    (102, "talha", "MECH", 60000),
    (103, "afaaz", "CSE", 55000),
    (104, "sai", "ECE", 70000)
]

for ele in employees:
    print(f"ID : {ele[0]}\nNAME : {ele[1]}\nDEPT : {ele[2]}\nSalary : {ele[3]}\n")

highest = employees[0]

for emp in employees:
    if emp[3] > highest[3]:
        highest = emp

print("\nEmployee with Highest Salary:")
print("ID:", highest[0])
print("Name:", highest[1])
print("Department:", highest[2])
print("Salary:", highest[3])

# %%
## create a dictioary to store student details
## roll number:{name,branch,cgpa}
## write a python program to:
    #add a new student
    #update a student's cgpa
    #delete a student record
    #search for a student using roll number
    #display all student record

student={}

while True:
    print("STUDENT DETAILS -")
    print("1-ADD NEW STUDENT")
    print("2-UPDATE STUDENT CGPA")
    print("3-DELETE STUDENT RECORD")
    print("4-SEARCH WITH STUDENT ROLL NO:")
    print("5-DISPLAY ALL STUDENT RECORD")

    choice=int(input("enter your choice:"))

    if choice==1:
        roll=int(input("enter roll number:"))
        name=input("enter name:")
        cgpa=float(input("enter cgpa:"))
        branch=input("enter branch:")

        student[roll] = {
            "name": name,
            "branch": branch,
            "cgpa": cgpa
        }

    elif choice==2:

    elif choice
